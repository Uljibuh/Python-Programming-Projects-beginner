# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
print('sainu mongolchuuda')

# %%
12*12

# %%
for i in range(10):
    print(i)

# %%
# statements
a = 10 + 12
e = a +1
print(a)
print(e)

# %%
# variables
python = 122
love_python = 33
love_python2 = 323
print(python)
print(love_python)
print(love_python2)

# %%
# types 
ner = 'ner' # a string
ner = 22.0   # floating potints
ner = 222    # an integer

# %% [markdown]
# # Too # Numbers

# %%
# Booleans have two values

yes = True
no = False

print(yes)
print(no)

# %%
# intergers
b = 213123
g = -1231438484746456282
k = 10010101 # binary
print(k)

# %% [markdown]
# **common operation # urgerj heregldeg bodlog**

# %%
# nemeh # add
1 + 2

# %%
# hasah # subtract
2 - 1

# %%
# urjuleh # multiply
3 * 3

# %%
# hovooh # divide
# produces an float
9 / 4

# %%
# buhleer hovooh # floor divide 
# produces an integer
9 // 4

# %%
# zereg devshuleh # power
2**3

# %%
# absolute value
abs(-3)

# %% [markdown]
# **float**

# %%
a = 3.1 + 3.1
a

a==6.2

# %% [markdown]
# **using math module**

# %%
import math

a = math.sqrt(4)
b = math.sqrt(9)
print(a,b)

# %%
c = math.sin(4)
c

# %%
d = math.cos(4)
b

# %%
e = math.tan(4) 
e

# %%
f = math.log(4)
f

# %% [markdown]
# **haricholah # comparisons**

# %%
a > b  
a < b
a >= b
a <= b
a == b  # tengchu, equal to
a != b  # tengchu bos # not equal to

# %% [markdown]
# **converting numbers**

# %%
# convert a to integer
a = 45.454
int(a)

# %%
# convert b to float
b = '43.343'
float(b)

# %% [markdown]
# # Strings

# %%
# single quote
a = 'how are you'

# double quote
b = "I am fine, and you"

# triple quotes
c = '''
hello python, let's start the journey
'''

print(a,b,c)

# %% [markdown]
# **string indexing**

# %%
a = 'mongolchuud'
b = a[0]
c = a[1]
d = a[-1]
e = a[-2]
print(b,c,d,e)

# another way

f = a[:3]
g = a[3:]
t = a[0:5]
k = a[-4:]
print(f,g,t,k)

# %% [markdown]
# **string operations**

# %%
# nemeh # concatebation
a = 'bi' + ' mongol'
b = a + ' hun'
print(a, b)

# %%
# ortin hemze # length
p = 'mongol'
len(p)

# %%
p = 'mongol'
r = 'm' in p # True

h = 'e' in p 
print(r,h)

# %%
# urjuleh # replication
m = p*10
m

# %% [markdown]
# **string method**

# %%
p = ' mongol hun baina daa '

r = p.strip()
print(p)
print(r)

# %%
# case conversion
p = ' mongol hun Baina daa '
l = p.lower()


u = p.upper()
print(l,u)

# %%
# replacing text
p = ' mongol hun Baina daa '
t = p.replace('hun', 'humun')
t

# %%
# string conversion
p = 34
str(p)

# %% [markdown]
# # Lists

# %%
# creating a list
sport =['ball','car','horse']
number = [23,3,32,34]
print(sport, number)

# %%
# split method
port = 'ball,car,horse'
sports = port.split(',')
sports

# %%
# list operation
sport =['ball','car','horse']
sport.append('run') # add at end


sport.insert(2, 'swim') # insert in second position
print(sport)

# %%
a = [1,2,4]
b = ['c','d','k']
a + b

# %%
b = ['c','d','k']
b[0]
b[1]
b[2]

# %%
# change items in a list
b[1] = 'oo'
b

# %%
# legth of the list
len(b)

# %%
b
w = b*4
print(w)

# %%
# lsit iteration 
for i in w:
    print('c')

# %%
# list removal
b = ['l','r','g','q']
b.remove('r')
b

# %%
# lsit sorting
a = [3,4,1,2,4,5,6,7,8]
a.sort()
a

# %%
#reverse order
s = [1,5,6,7,8]
s.sort(reverse=True)
s

# %%
# list and math
a = [1,2,3,4,5]
b = a * 2
b

# %%
symlist = ['HPQ', 'AAPL', 'AIG', 'MSFT', 'YHOO', 'GOOG']
for s in symlist:
        print('s =', s)
